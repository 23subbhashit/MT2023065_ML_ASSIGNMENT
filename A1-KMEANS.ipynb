# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Lenovo/Desktop/IIIT B NOTES/ML/Assignment1/football.csv")

# %%
data.head()
# Out:
#    sofifa_id         short_name  overall  potential    value_eur  wage_eur  \
# 0     158023           L. Messi       93         93   78000000.0  320000.0
# 1     188545     R. Lewandowski       92         92  119500000.0  270000.0
# 2      20801  Cristiano Ronaldo       91         91   45000000.0  270000.0
# 3     190871          Neymar Jr       91         91  129000000.0  270000.0
# 4     192985       K. De Bruyne       91         91  125500000.0  350000.0
#
#    age  height_cm  weight_kg  club_team_id  ... defending_marking_awareness  \
# 0   34        170         72          73.0  ...                          20
# 1   32        185         81          21.0  ...                          35
# 2   36        187         83          11.0  ...                          24
# 3   29        175         68          73.0  ...                          35
# 4   30        181         70          10.0  ...                          68
#
#   defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                        35                        24                   6
# 1                        42                        19                  15
# 2                        32                        24                   7
# 3                        32                        29                   9
# 4                        65                        53                  15
#
#    goalkeeping_handling goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                  15                       14
# 1                     6                  12                        8
# 2                    11                  15                       14
# 3                     9                  15                       15
# 4                    13                   5                       10
#
#    goalkeeping_reflexes  goalkeeping_speed contribution_type
# 0                     8                NaN                 1
# 1                    10                NaN                 1
# 2                    11                NaN                 1
# 3                    11                NaN                 1
# 4                    13                NaN                 1
#
# [5 rows x 66 columns]

# %%
data.groupby(['club_team_id']).mean()
# Out:
#                   sofifa_id    overall  potential     value_eur  \
# club_team_id
# 1.0           216642.000000  80.272727  83.727273  2.959091e+07
# 2.0           220136.181818  77.636364  82.000000  1.799091e+07
# 3.0           223065.545455  70.181818  76.272727  2.927273e+06
# 4.0           215958.909091  65.363636  68.727273  9.613636e+05
# 5.0           213061.454545  83.363636  85.636364  4.754545e+07
# ...                     ...        ...        ...           ...
# 115530.0      230344.090909  71.272727  71.272727  2.345455e+06
# 115535.0      242645.000000  64.636364  70.545455  9.340909e+05
# 115536.0      254503.545455  61.818182  66.909091  5.718182e+05
# 115716.0      234605.636364  62.909091  68.000000  7.881818e+05
# 115820.0      239379.727273  61.727273  64.818182  4.727273e+05
#
#                    wage_eur        age   height_cm  weight_kg  league_level  \
# club_team_id
# 1.0            82272.727273  25.454545  183.727273  76.727273           1.0
# 2.0            56545.454545  24.909091  182.454545  74.545455           1.0
# 3.0            20363.636364  24.181818  183.000000  72.181818           2.0
# 4.0             3000.000000  26.363636  182.363636  76.727273           3.0
# 5.0           138727.272727  26.818182  182.909091  79.272727           1.0
# ...                     ...        ...         ...        ...           ...
# 115530.0       10181.818182  25.000000  177.272727  73.545455           1.0
# 115535.0         504.545455  25.636364  177.727273  71.545455           1.0
# 115536.0         500.000000  25.909091  182.000000  76.909091           1.0
# 115716.0        2272.727273  25.636364  179.727273  75.272727           1.0
# 115820.0         759.090909  25.454545  183.181818  76.545455           3.0
#
#               club_jersey_number  ...  defending_marking_awareness  \
# club_team_id                      ...
# 1.0                    11.090909  ...                    61.272727
# 2.0                    10.909091  ...                    59.181818
# 3.0                    12.181818  ...                    53.363636
# 4.0                     9.000000  ...                    50.545455
# 5.0                    11.545455  ...                    62.454545
# ...                          ...  ...                          ...
# 115530.0                9.909091  ...                    49.636364
# 115535.0               18.000000  ...                    46.272727
# 115536.0               14.818182  ...                    41.363636
# 115716.0               18.909091  ...                    47.090909
# 115820.0               15.363636  ...                    41.090909
#
#               defending_standing_tackle  defending_sliding_tackle  \
# club_team_id
# 1.0                           60.000000                 59.636364
# 2.0                           60.363636                 56.545455
# 3.0                           55.818182                 55.000000
# 4.0                           50.636364                 45.909091
# 5.0                           66.363636                 62.454545
# ...                                 ...                       ...
# 115530.0                      50.272727                 48.181818
# 115535.0                      52.909091                 45.545455
# 115536.0                      47.818182                 43.454545
# 115716.0                      51.545455                 48.818182
# 115820.0                      43.000000                 44.181818
#
#               goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# club_team_id
# 1.0                    16.818182             17.818182            17.727273
# 2.0                    18.181818             17.454545            17.454545
# 3.0                    15.909091             15.181818            17.454545
# 4.0                    15.909091             15.000000            16.181818
# 5.0                    17.545455             17.727273            17.181818
# ...                          ...                   ...                  ...
# 115530.0               15.727273             15.454545            16.363636
# 115535.0               15.000000             15.454545            14.454545
# 115536.0               15.090909             15.727273            14.363636
# 115716.0               15.909091             13.363636            14.363636
# 115820.0               15.454545             15.454545            15.090909
#
#               goalkeeping_positioning  goalkeeping_reflexes  \
# club_team_id
# 1.0                         15.000000             16.636364
# 2.0                         17.272727             17.090909
# 3.0                         15.818182             16.000000
# 4.0                         15.636364             16.272727
# 5.0                         16.272727             16.545455
# ...                               ...                   ...
# 115530.0                    16.272727             13.909091
# 115535.0                    15.636364             14.818182
# 115536.0                    14.181818             14.545455
# 115716.0                    15.090909             14.090909
# 115820.0                    13.454545             15.363636
#
#               goalkeeping_speed  contribution_type
# club_team_id
# 1.0                        55.0           0.363636
# 2.0                        58.0           0.454545
# 3.0                        46.0           0.454545
# 4.0                        29.0           0.454545
# 5.0                        35.0           0.454545
# ...                         ...                ...
# 115530.0                   45.0           0.454545
# 115535.0                   22.0           0.454545
# 115536.0                   33.0           0.545455
# 115716.0                   40.0           0.454545
# 115820.0                   39.0           0.636364
#
# [701 rows x 57 columns]

# %%
col = data.columns[data.isna().any()].tolist()
col = col + ["sofifa_id","short_name" ]

# %%
x = data.drop(col,axis=1)

# %%
x.head()
# Out:
#    overall  potential  age  height_cm  weight_kg preferred_foot  weak_foot  \
# 0       93         93   34        170         72           Left          4
# 1       92         92   32        185         81          Right          4
# 2       91         91   36        187         83          Right          4
# 3       91         91   29        175         68          Right          5
# 4       91         91   30        181         70          Right          5
#
#    skill_moves  international_reputation    work_rate  ...  \
# 0            4                         5   Medium/Low  ...
# 1            4                         5  High/Medium  ...
# 2            5                         5     High/Low  ...
# 3            5                         5  High/Medium  ...
# 4            4                         4    High/High  ...
#
#   mentality_composure  defending_marking_awareness  defending_standing_tackle  \
# 0                  96                           20                         35
# 1                  88                           35                         42
# 2                  95                           24                         32
# 3                  93                           35                         32
# 4                  89                           68                         65
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                        24                   6                    11
# 1                        19                  15                     6
# 2                        24                   7                    11
# 3                        29                   9                     9
# 4                        53                  15                    13
#
#    goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 0                   15                       14                     8
# 1                   12                        8                    10
# 2                   15                       14                    11
# 3                   15                       15                    11
# 4                    5                       10                    13
#
#    contribution_type
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
#
# [5 rows x 46 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
categorical_features = ["preferred_foot","work_rate","body_type" ]
for each in categorical_features:
    x[each] = encoder.fit_transform(x[each])

# %%
def plot_clusters(X, centers, labels, title):
    plt.figure(figsize=(8, 6))
    plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', s=10, label='Data Points')
    plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', s=200, label='Centroids')
    plt.title(title)
    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
X= x.iloc[:, :].values
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans = KMeans(n_clusters= i, init='k-means++', random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)     
plt.plot(range(1,11), wcss,)
plt.title('The Elbow Method')
plt.xlabel('No of clusters')
plt.ylabel('Intertia for that cluster')
plt.show()

# %%
k = 3
kmeans = KMeans(n_clusters = k, random_state = 0).fit(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[6.96276446e+01 7.25063470e+01 2.84753173e+01 1.88991537e+02
#   8.27743300e+01 8.68829337e-01 2.55430183e+00 1.00000000e+00
#   1.17912553e+00 8.00000000e+00 4.53737659e+00 1.45669958e+01
#   1.22849083e+01 1.45035261e+01 2.93906911e+01 1.27080395e+01
#   1.46318759e+01 1.55444288e+01 1.46868829e+01 2.83060649e+01
#   2.13342736e+01 4.03173484e+01 4.03653032e+01 4.17348378e+01
#   6.45260931e+01 4.33300423e+01 4.94203103e+01 5.97066291e+01
#   3.16897038e+01 6.22891396e+01 1.29308886e+01 2.75275035e+01
#   1.75373766e+01 1.15726375e+01 4.32031030e+01 2.05430183e+01
#   4.64866008e+01 1.56755994e+01 1.43610719e+01 1.42299013e+01
#   6.98392102e+01 6.73667137e+01 6.57094499e+01 6.88011283e+01
#   7.12073343e+01 6.66133815e-16]
#  [6.99351392e+01 7.28812127e+01 2.67450298e+01 1.78816849e+02
#   7.32219185e+01 7.42793241e-01 3.20825050e+00 2.95427435e+00
#   1.19607356e+00 4.40482107e+00 3.33871769e+00 6.20228628e+01
#   6.35250994e+01 5.69132704e+01 6.80201292e+01 5.81282306e+01
#   6.94850895e+01 6.25613817e+01 5.63986083e+01 6.14664513e+01
#   7.01123260e+01 7.28859344e+01 7.22470179e+01 7.34184891e+01
#   6.66692346e+01 7.17562127e+01 6.88536282e+01 6.59642147e+01
#   7.22984592e+01 6.55698310e+01 6.37611829e+01 5.97507455e+01
#   4.69995030e+01 6.66423956e+01 6.53049205e+01 6.03556163e+01
#   6.62144632e+01 4.70328032e+01 4.76615308e+01 4.44965209e+01
#   1.04527833e+01 1.04925447e+01 1.05124254e+01 1.04488072e+01
#   1.04706759e+01 7.84791252e-01]
#  [6.72691675e+01 7.08907535e+01 2.64422507e+01 1.83264561e+02
#   7.69414281e+01 7.43007568e-01 2.82494242e+00 2.14017769e+00
#   1.07699901e+00 5.84435670e+00 3.84698914e+00 4.99394538e+01
#   3.66275090e+01 6.20437644e+01 6.26324449e+01 3.48216519e+01
#   5.40704179e+01 4.26669957e+01 3.80358671e+01 5.74202040e+01
#   6.03313590e+01 6.27555117e+01 6.38868049e+01 6.01556433e+01
#   6.30282988e+01 6.08259296e+01 5.22579796e+01 7.06284962e+01
#   7.05399803e+01 7.30602172e+01 4.02987825e+01 6.73922343e+01
#   6.52606120e+01 4.51513656e+01 4.92615992e+01 4.30822639e+01
#   5.99539322e+01 6.52007239e+01 6.71322804e+01 6.49470220e+01
#   1.05090490e+01 1.04205331e+01 1.04794340e+01 1.05205660e+01
#   1.04271142e+01 1.27673577e-01]]

# %%
plot_clusters(X, kmeans.cluster_centers_, kmeans.labels_, "K-means optimal clustering")

# %%
import matplotlib.pyplot as plt
X= x.iloc[:, 11:45].values
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans = KMeans(n_clusters= i, init='k-means++', random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)     
plt.plot(range(1,11), wcss,)
plt.title('The Elbow Method')
plt.xlabel('No of clusters')
plt.ylabel('Intertia for that cluster')
plt.show()

# %%
k = 3
kmeans = KMeans(n_clusters = k, random_state = 0).fit(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[14.56699577 12.28490832 14.50352609 29.39069111 12.70803949 14.63187588
#   15.54442877 14.68688293 28.30606488 21.33427362 40.31734838 40.36530324
#   41.7348378  64.52609309 43.33004231 49.4203103  59.70662906 31.68970381
#   62.28913963 12.93088858 27.52750353 17.53737659 11.57263752 43.20310296
#   20.54301834 46.48660085 15.67559944 14.36107193 14.22990127 69.83921016
#   67.36671368 65.70944993 68.80112835 71.20733427]
#  [62.00348345 63.55610848 56.92659866 68.01816372 58.15327196 69.48619059
#   62.5618313  56.4162727  61.47076387 70.11072406 72.87036576 72.24010948
#   73.39363026 66.66683255 71.71460562 68.87335158 65.9601891  72.28489674
#   65.61059965 63.77705897 59.74297089 46.97014183 66.65812391 65.31749191
#   60.38417517 66.22095049 47.00945509 47.6305051  44.46454342 10.44986315
#   10.49241105 10.51057477 10.44886788 10.47300323]
#  [49.9848883  36.63074901 62.01773982 62.64388962 34.82687254 54.09428384
#   42.69908016 38.04270696 57.42115637 60.34954008 62.79270696 63.90965834
#   60.21024967 63.03745072 60.89881735 52.25919842 70.6261498  70.5607753
#   72.99408673 40.31636005 67.38994744 65.26938239 45.16590013 49.27135348
#   43.07293035 59.95565046 65.20170828 67.1412615  64.95565046 10.51281209
#   10.42082786 10.48193167 10.52036794 10.42411301]]

# %%
plot_clusters(X, kmeans.cluster_centers_, kmeans.labels_, "K-means optimal clustering")
